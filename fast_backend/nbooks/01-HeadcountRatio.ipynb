# %%
import pandas as pd

# %%
df = pd.read_excel('../data/data_La_Réunion_2.xls', "esfact7-ElPR1")
df
# Out:
#      i_new  Revenu_Imputé_2  Unnamed: 2  Freq Nombre de Jours sans pluie  \
# 0        1       226.876361           1                         0.272727
# 1        2       840.212349           2                         0.327731
# 2        3      1756.374230           3                         0.519231
# 3        4      2502.849418           4                         0.765027
# 4        5      1293.317405           5                         0.805714
# ..     ...              ...         ...                              ...
# 453    454       419.468894         454                         0.679775
# 454    455       244.749612         455                         0.427632
# 455    456       373.217389         456                         0.629630
# 456    457       391.774118         457                         0.677419
# 457    458       398.938516         458                         0.540541
#
#      nbjour  nbjsp  uc1  revenu  Revenu imputé  nbpers  nenf  \
# ...
