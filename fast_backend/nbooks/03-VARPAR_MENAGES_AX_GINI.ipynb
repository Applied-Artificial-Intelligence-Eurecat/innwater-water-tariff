# %%
import pandas as pd

df =pd.read_csv('../data/simulation_data/20/middle_metrics.csv')
df['VAR_PAR_Menages AX']
# Out:
# 0      10.796324
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
#          ...
# 453    47.236786
# 454    62.961522
# 455    27.724578
# 456    26.054472
# 457    25.409676
# Name: VAR_PAR_Menages AX, Length: 458, dtype: float64
