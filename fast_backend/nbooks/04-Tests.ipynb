# %%
import pandas

df = pandas.read_csv('/Users/oriol.alas/Projects/INNWATER/water-tariff-tests/middle_metrics.csv')

# %%
df['C_PP BM']
# Out:
# 0      28.023695
# 1      30.000000
# 2      35.333789
# 3      52.339042
# 4      48.423065
#          ...
# 453    22.591648
# 454    19.920426
# 455    16.371826
# 456    16.855996
# 457    16.092442
# Name: C_PP BM, Length: 458, dtype: float64

# %%
(df['C_EP_BCP HM'] - df['C_PP BM']).nub
# Out:
# 0     -3.296166
# 1      0.834289
# 2      1.935678
# 3      2.479535
# 4      2.802993
#          ...
# 453    1.084680
# 454    1.010135
# 455    1.299743
# 456    1.285779
# 457    1.327644
# Length: 458, dtype: float64

# %%
df['C_EP_BCP HM']
# Out:
# 0      24.727529
# 1      30.834289
# 2      37.269466
# 3      54.818577
# 4      51.226058
#          ...
# 453    23.676329
# 454    20.930560
# 455    17.671569
# 456    18.141775
# 457    17.420086
# Name: C_EP_BCP HM, Length: 458, dtype: float64
